# %%
# fardin 
"""
ajasjhd
"""
# a=5
# b=10
# c=a+b
# print(c)
# Out:
# 15

# %%
"""
Class 2
"""

"""
Data Type
"""

#PRIMITIVE DATA TYPE (fundamental) - INTEGERS, FLOAT, STRING, BOOLEAN, NONE, COMPLEX 
#box - contain only 1 value
#INTEGERS
# age= 18
# print(age)

# #FLOAT - Decimals
# pi=3.14
# print(pi)

# #STRING - word / sentances / characters
# name= "Fardin Khan"
# Hobby= "Love To Learn New Things" 
# favAlpha= "a"
# print(name, Hobby, favAlpha)

# #BOOLEAN - true, false
# passed= True
# print(passed)

# #NONE - nothing
# car= None
# print(car)

# #COMPLEX - real + imaginary 
# z= 2+3j
# print(z)

# PI = 3.14   #it value should not change - caution
# print(2*PI*10)

# #DERIVED DATATYPES - these are made up of primitive datatypes
# #box - contain more than 1 value

# #LIST - array (different language)
# fruits = ["apple", "mango",1,2,3,True]
# print(fruits)

# #TUPLE - fixed list - can't add, remove , imutable
# favFruits = ("mango", "guava")
# print(favFruits)

# #SET - unique items 
# numbers = {1,2,3,4,4,4,4}
# print(numbers)

# #FROZENSET - fixed set - can't add, remove, imutable, unique items
# frozen = frozenset([1,2,3,4,4,4])
# print(frozen)

# #DICTIONARY - key : value
# studentMark = {
#     "geeta":45,
#     "fardin":99,
#     "alifa":85,
# }
# print(studentMark)
# Out:
# '\nData Type\n'

# %%
'''
class 03 - Operators

Type of operator
1. Unary - 1 operand
2. Binary - 2 operand
3. Tertiary - 3 operand

'''

# BINARY
# a = 5
# b = 10
# c = a + b 
# a, b are operands
# '+' is an operator

# UNARY
# d = -a
# a is an operand
# '-' is an operator
# print(a)
# print(d)

'''
ARITHEMETIC OPERATORS
+ - * / // % **
'''
# a = 5
# b = 8
# print("#### ARITHEMETIC OPERATORS ####")
# print( a+b )
# print( a-b )
# print( a*b )
# print( b/a )
# print( b//a )  # floor
# # floor of 1.6 - 1
# # ceil of 1.6 - 2
# print( b%a )  # remainder
# print( 5**3 )  # power 5 ^ 3

'''
COMPARSION OPERATORS -> True/False
'''
# a = 5
# b = 8
# print("#### COMPARISON OPERATORS ####")
# print(a == b)
# print(a < b)
# print(a > b)
# print(a != b)  # ! -> not
# print(a <= b)
# print(a >= b)

'''
ASSIGNMENT OPERATORS
'''
# a = 10
# print(a)
# a += 5 # a = a + 5
# print(a)
# a /= 3
# print(a)
# a *= 10
# print(a)
# a %= 3  # a = a % 3
# print(a)
# a **= 5  # a = a ** 5 = a ^ 5 = 2 ^ 5 = 32
# print(a)
# a //= 15  # a = a // 15 -> a / 15 = 32 / 15 = 2.13 ~ floor = 2
# print(a)

'''
LOGICAL OPERATORS
and, or, not

True - 1
False - 0

and - multiply
or - addition
'''
# print(not True)
# print(not False)
# print(False and False)
# print(False and True)
# print(True and True)
# print(True and False)
# print(False or False)
# print(False or True)
# print(True or True)
# print(True or False)
# print(10 > 5 and 10 < 9)

'''
MEMBERSHIP & IDENTITY OPERATOR
'''
# print( "a" in "cat" )
# print( "b" in "cat" )
# print( "b" not in "cat" )
# print( "c" not in "cat" )
# a = 5
# b = a
# c = 5
# print( a is b )
# print( a is c )

# x = [1,2,3]
# y = x
# z = [1,2,3]
# print(x is y)
# print(x is z)


'''
BITWISE OPERATOR
works on bits (0,1)
'''
# print(5 & 3)
# print(5 | 3)
# print(5 ^ 3)
# print(5 << 1)  # left shift (bits)
# print(5 >> 1)  # right shift (bits)
# Out:
# True
# False
# '\nBITWISE OPERATOR\nworks on bits (0,1)\n'

# %%
"""
Class 4

LOOPS AND CONDTIONALS
"""

# #how to take input in the program?
# num = int(input("Enter your number to get square of it:"))
# print(num**2)
# num = int(input("Enter a Number:"))
# print(num)
# name = input("Enter your name:")
# print(name)

#grading system
# marks=int(input("Enter Your Marks:"))

# if marks >=90:
#     print("Grade: A")

# elif marks >=80:
#     print("Grade: B")

# elif marks >=70:
#     print("Grade: C")

# else: 
#     print("Grade: D")


# TRAFFIC LIGHT
# light = input("enter traffic light color (red/yellow/green)")
# if light =="red":
#     print("Stop")
# elif light == "yellow":
#     print("Get Ready")
# elif light == "green":
#     print("Go")
# else:
#     print("Invalid Input")
    

"""
#LOOPS - repeating/iterative
"""
"""
#FOR LOOPS 
"""
# users = ["Fardin","jadu","alifa","tanzil","kashish",44,55,50.50,True]

# for user in users:
#     print(user)

# nums = [51,62,54,78,9,32,4,56,78,76]
# totalSum=0

# for num in nums:
#     totalSum += num

# print(totalSum)

"""
range
"""

# for i in range(1,11):
#     print(I)

# num = int(input("Enter a Number to Get Table of it:"))
# for i in range(1,11):
#     print(num * I)



"""
#WHILE LOOPS 
"""

# #ATM Pin Verification
# correct_pin="1020"
# attempt=""

# while attempt != correct_pin:
#     attempt = input("Enter a PIN:")

# print("Access Granted")

# PRINT VALUES
# a = 50
# while a <= 100:
#     print(a)
#     a = a + 1


#BREAK & CONTINUE
#Break - break the loop

# items=["Fardin","jadu","alifa","tanzil","kashish"]

# while items == "alifa":
#     break
# print("alifa")

# for item in items:
#     if item == "alifa":
#         break
#     print(item)

#Continue -continue the loop

# for i in range(1,6):
#     if i == 2:
#         continue
#     print(i)
# Out:
# '\n#WHILE LOOPS \n'

# %%
"""
Class 5

STRINGS - Sequence of characters enclosed in quotes
"""

# name1 = 'Fardin'
# print(name1)

# #Multiline string
# name = '''
# fardin 
# firoz
# khan
# '''
# print(name)

# name =  "fardin"
# print(name[4])
# print(name[-3]) # Value form the end (not all lang supports this)

#SLICING
# name = 'Fardin Khan'
# print(name[0:6])
# print(name[2:6])
# print(name[:6])
# print(name[7:])
# print(name[7:9])

# COUNT
# name = 'Fardin Khan'
# print(name.count("a"))
# print(name.count("k"))
# print(name.count("g"))

#STRIP
# name = '      Fardin Khan      '
# print(name)   #      Fardin Khan      
# print(name.strip()) #Fardin Khan
# print(name.lstrip()) #Fardin Khan      
# print(name.rstrip()) #      Fardin Khan
# name = "----LEARN BAY----"
# print(name)
# print(name.strip('-'))

# INDEX VS FIND
# name =  "fardin"
# print(name.index('a'))
# # print(name.index('z'))    # character not present in string, it throws ValueError
# print(name.find('d'))
# print(name.find('m'))       # -1

# STARTWITH , ENDWITH
# name = 'I am a student at learnbay'
# print(name.startswith('learn')) #f
# print(name.endswith('learnbay')) #t

#FORMAT
# names = ['Ankit', 'Imra', 'Surendra']
# template = '''
# Hi {} sir/mam,
# Welcome to our amazing platform and enjoy this day.
# '''
# for name in names:
#     print(template.format(name))

# name = "Omraj Sharma"
# phone = "7503047413"
# email = '''
# Hi {} sir/madam
# We're love to welcome you on our place. Please comfirm your phone number {}
# '''
# print(email.format(name, phone))

# # UPPER & LOWER
# name = 'fardin'
# print(name.upper())
# name = 'FaRdiN'
# print(name.lower())

# #SWAPCASE
# name = 'FaRdiN'
# print(name.swapcase()) #fArDIn

# REPLACE
# favouriteFood = "apples are sweet"
# print(favouriteFood)
# print(favouriteFood.replace('apples','Fardin'))
# print(favouriteFood.replace('apples',''))

#RFIND
# name = 'fardin'
# print(name.find('r')) #2
# print(name.rfind('a')) #
# print(name.rfind('A')) #-1

#RINDEX
# name = 'fardin'
# print(name.rindex('Z'))  # ValueError

#TITLE
# name = 'fardin'
# print(name.title())


# #ISALPHA - check alphabates
# name = 'fardin'
# print(name.isalpha()) #t

# name = 'fardin34424'
# print(name.isalpha()) #f

#ISALNUM a-z, A-Z, 0-9
# name = 'fardin'
# print(name.isalnum()) #t

# name = 'fardin2452'
# print(name.isalnum()) #t

# name = 'fardin 2452'
# print(name.isalnum()) #f

# name = '434522452'
# print(name.isalnum()) #t


#ISUPPER
# name = 'FARDIN'
# print(name.isupper()) #t

# #ISLOWER
# name = 'FARDIN'
# print(name.islower()) #F

# ISTITLE
# name = "fardin"
# print(name.istitle()) #f

# name = "Fardin"
# print(name.istitle()) #t

#JOIN
# name = ["fardin0","Raju","Ram"]
# print(name)
# print(" ".join(name))
# print("".join(name))
# print("-".join(name))
# print(.join(name)) #Errors

# ISSPACE - it check string have only space or not
# name = "           "
# print(name.isspace()) #t
# name = "     s      "
# print(name.isspace()) #f

#ISDIGIT
# name = "251"
# print(name.isdigit()) #t
# print("1/2".isdigit()) #f because it is decimal
# print("1.254".isdigit()) #f because it is decimal
# print("5565654".isdigit()) #t
# print("²³".isdigit()) #t ****

#ISDECIMAL - it is not to check decimal, it is strict version of isdigit(it also check for power values)
# print("5456".isdecimal()) #t
# print("1/2".isdecimal()) #f because it is decimal
# print("1.254".isdecimal()) #f because it is decimal
# print("5565654".isdecimal()) #t
# print("²³".isdecimal()) #f ****

#ISNUMERIC - all characters including fraction, superscripts, roman numerals
# print("12".isnumeric()) #t
# print("Ⅻ".isnumeric()) #t
# print("¼".isnumeric()) #t
# print("123abc".isnumeric()) #f

# ISPRINTABLE - if all characters are printable (not like \n, \t)
# print("hello\n world \t on earth".isprintable())
# print("Fardin".isprintable())
# Out:
# apples are sweet
# Fardin are sweet
#  are sweet

# %%
"""
Class 6

LIST - Collection of items

features:
1.ordered
2.changeable
3.duplicates
4.any data type
"""
# nums = [1,3,5,7,9,11]  # nums - list of integers
# names = ["Amit", "Sucheta", "Swaroop"]  # names - list of strings
# ans = [True, False, True, False, False]  # ans - list of boolean
# mix_list = [1, "apple", True, 2.5]  # only valid in few language


#INDEXING
# lists = [1,"apple", True,2.5]  # only valid in few language
# print(lists[1])
# print(lists[-2])

#SLICING
# lists = [1,"apple", True,2.5]
# nums = [43, 65, 2, 4, 6, 43, 2, 34, 23, 45, 7, 87, 43]
# print(lists[:3])
# print(nums[:10:3])

# NESTED LIST - List of List
# mobile = [
#     ["Iphone", "Samsung"],
#     ["Oneplus", "Nothing"]
# ]
# print(mobile[1][0])

# LIST METHODS

# APPEND - insert value at end
# print(names)
# names.append("Fardin")
# names.append("Fardin")
# print(names)


# # INSERT - insert value at index
# names.insert(2,"raj")
# print(names)
# names.insert(2,6556555)
# print(names)

# #REMOVE - frist match of the value
# names.remove("Fardin")
# print(names)

# #POP - remove last item and also use to remove value from index
# names.pop()
# print(names)

# names.pop(2)
# print(names)

# # REVERSE - revers the list
# names.reverse()
# print(names)

# # COUNT
# names.append("raj")
# print(names)
# print(names.count("raj"))

# #INDEX - it is used to find the index of value and it will find first idex  #ValueError
# print(names.index("Amit"))
# print(names.index("raj"))

# COPY 
# names2 = names 
# names2 = names
# print("names:",names)
# print("names2:",names2)

# names.pop(1)
# print("names:",names)
# print("names2:",names2)

# names2 = names # Shallow Copy - both the variables are pointing to the same memory
# names2 = names.copy() # Deep copy - both the variables are having different list
# names.pop(1)
# print("names:",names)
# print("names2:",names2)


# TUPLE - Immutable List, Frozen list

# t = (1,4,6,3,8,8,8,8)
# print(t.count(8))
# print(t.count(3))
# print(t.index(6)) # Valueerror



'''
ASSIGNMENT
'''

# Create a list of your 5 favourite fruits
# fruits=["Apple","Cherry","Grapes","Watermelon","Avacado"]
# print(fruits)

# # Add a new fruit to the end of the list
# fruits.append("Lichi")
# print(fruits)

# # Insert a new fruit at position 2
# fruits.insert(2,"mango")
# print(fruits)

# # Slice of the list to get first 3 fruits
# print(fruits[:3])


# Find the maximum and minimum in a list
nums = [43, 65, 2, 4, 6, 43, 2, 34, 23, 45, 7, 87, 43]
# maxx = 0
# minn = 100000000
# for num in nums:
#     if num>maxx:
#         maxx=num
#     if num<minn:
#         minn=num
# print(maxx) 
# print(minn)

# Find the sum of all the elements in the list
# total=0
# for num in nums:
#     total = total + num # total += num
# print(total)    

# Check if the list is sorted or not (ascending)
# arr = [1,2,4,8,9,11,24,35,46,55]
# ans = True
# for i in range(0,len(arr)-1):
#     if arr[i] > arr[i+1]:
#         ans = False
#         break
# print(ans)
# Out:
# True

# %%
import copy
"""
Class 7

DICTIONARY - collection of key-value pairs

PROPERTY - 
1. Unordered
2. Mutable
3. Index by keys
4. Uniquq

"""

# Assinment - create a dictionary of your phone 
# phone = {
#     "company":"Samsung",
#     "ram":"12GB",
#     "memory":"256GB",
# }
# print(phone)
# # Access in Dictionary key
# print(phone["ram"])
# # print(phone["battry"]) #KeyError

# #GET
# print(phone.get("ram"))
# print(phone.get("battry"))
# print(phone.get("battry", "8000MAh"))


# ITERATION ON DICTIONARY
# employee = {
#     "name": "Fardin",
#     "company": "ABC",
#     "area": "Green Glen",
#     "city": "Bangalore",
#     "state": "Karnataka",
#     "age": "10",
#     "pin": "560103",
#     "phone": "7503047413",
#     "email": "omraj7413@gmail.com"
# }

# for i in employee:
#     # print(i,":", employee[i])
#     print(i[:2],":", employee[i][:2])


#NESTED DICTIONARY
# employee = {
#     "name": "Fardin",
#     "company": "ABC",
#     "age": "10",
#     "phone": "7503047413",
#     "email": "omraj7413@gmail.com",
#     "address": {
#         "area": "Green Glen",
#         "city": "Bangalore",
#         "state": "Karnataka",
#         "pin": "560103",
#     }
# }

# ACCESS IN NESTED DICTIONARIES
# print(employee)
# print(employee["age"])
# print(employee["address"])
# print(employee["address"]["pin"])
# print(employee.get("address"))


#SHALLOW COPY
# employee2 = employee
# employee["name"] = "Raj"
# employee2["name"] = "Soham"
# print(employee["name"])
# print(employee2["name"])


#DEEP COPY
# employee2 = copy.deepcopy(employee)
# employee["name"] = "Raj"
# employee2["name"] = "Soham"
# print(employee["name"])
# print(employee2["name"])


#KEYS
# print(employee.keys())


#VALUES
# print(employee.values())

#ITEMS
# for k , v in employee.items():
#     print(k,v)


#UPDATE
# car = {
#     "e":"1200cc",
#     "m":"tata"
# }
# print(car)
# car.update({"mi":"25","c":"black"})
# print(car)
# car.update({"e":"500cc"})
# print(car)


#POP
# car = {
#     "e":"1200cc",
#     "m":"tata"
# }
# print(car)
# # car.pop("e")
# en = car.pop("e")     #to get the value
# print(car)
# print(en)
# car.pop("xyz") # KeyError


#CLEAR
# car = {
#     "e":"1200cc",
#     "m":"tata"
# }
# print(car)
# car.clear()
# print(car)




# EMPLOYEE FILTER - (salary < 7500) - expected result dictionary {"Rajesh": 4500, "Ramesh": 7400}
# employee = {
#     "Ramu": 10000,
#     "Shyamu": 7500,
#     "Rajesh": 4500,
#     "Nitin": 2900,
#     "Ramesh": 7400
# }
# result = {}
# for k,v in employee.items():
#     if v < 7500:
#         result[k]=v
# print(result)
# Out:
# {'Rajesh': 4500, 'Nitin': 2900, 'Ramesh': 7400}

# %%
"""
Class 8

FUNCTIONS - 

"""
'''
REPEATING THE CODE
- Code duplicate
- Hard maintain
- Low reusability
'''
# a = 5
# b = 10 
# print(a+b)  # task

# x = 7
# y = 3
# print(x+y)

# p = 5
# q = 7
# print(p+q)

# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")
# print("Hello sir/madam, Welcome to learnbay. Keep learing")

'''
BENEFITS OF FUNCTIONS/METHOD - workers
- ORGANISE CODE
- REUSABLE
- READABILITY
'''

'''
create
use/call
'''

# def call():
#     print("Call to Fardin Khan")

# call()

# def call1(number):
#     if number == 1:
#         print("Call to Mom")
#     elif number == 2:
#         print("Call to Didi")
#     elif number == 3:
#         print("Call to Dad")
#     elif number == 4:
#         print("Call to Friend")
#     else: 
#         print("Wrong Number!!!!")

# call1(1)
# call1(2)
# call1(3)
# call1(4)
# call1(7)


# def waiter(req):
#     if req == "water":
#         return 'Water Bottle'
#     if req == 'menu':
#         return 'Menu Card'
#     if req == 'bill':
#         return 'Food Bill'
#     else:
#         return 'Sorry Sir/Madam'

# waiter("water")
# a = waiter("bill")
# print(a)
# print(waiter("menu"))

#ARGUMENT - value that are pass inside a function - in waiter function/method is argument is "req"

#DEFAULT ARGUMENTS 

# def greet(name):
#     print('hello ' +name+ ' sir/madam, welcome to our mall')

# greet('fardin')
# greet() #error - greet() missing 1 req positional argument: 'name'

# Guest is a default argument
# def greet(name = "Guest"):
#     print('hello ' +name+ ' sir/madam, welcome to our mall')

# greet('fardin')
# greet()




#MULTIPLE ARGUMENT
# def addNum(a,b):
#     print(a+b)

# addNum(10,20)
# addNum(5,15)
# addNum(2,5)

#ARGUMENT ORDER
# def addNum(a,b):
#     print(a)
#     print(b)
#     print(a+b)

# # addNum(10,20)
# addNum(b=10,a=20)     # not recommentded

# VARIABLE LENGTH ARGUMENTS

# def addNum(*nums):
#     print(nums)

# addNum(1,5,6,7,8,9,3)

# def addNum(*nums):
#     total = 0
#     for num in nums:
#         total += num
#     print(total)

# addNum(1,5,6,7,8,9,3)
# addNum(1,5,)
# Out:
# 39
# 6

# %%
"""
Class 9

MODULES - 

Organizing
Avoid repetitions
Maintainance
Predefind
Reusability
"""

from discount import apply_discount, card_discount
from dc import applyDc, menu

price = 1000
discountPercentage = 20


fp = applyDc(price,discountPercentage)
print(fp)

m = menu("water")
print(m)
# final_Price = apply_discount(price,discountPercentage)
# print(final_Price)

# c = discount.card_discount(100, "SBI")
# print(c)

# c = discount.card_discount(1000, "HDFC")
# print(c)
# Out:
# 800.0
# Not Available

# %%
"""
Class 10

MORE INTO FUNCTIONS
"""

# %%
"""
Class 11

FILE MANAGEMENT / HANDLING

- read
- update

Benifits
- Data permanent
- Share data between programs

Types of fiels
1. Text files - (.txt, .csv, .log, .html, .css, .py, .js etc.......)
2. Binary files - (audio, video, pdf, exe, .jpg, .pdf, .exe, .mp3 etc.........)

Basic file operation
1. Open a file - open()
2. Read from file - 
3. Write from file - 
4. Close a file - close()

File Modes
r - read (default)
w - write
a - append (add to end of file)
b - binary (rb, wb)
x - create (fails if file exists)
+ - read and write

LOG FILES - 100GB
extract - logs related to payment - 
create a new file - put only payment logs into it - 3 GB  - 100 Years -> 1 mins

file scrape data
- csv data -> excel data

"""
# f = open("sample.txt", "r")
# print(f.read()) # Read entire file content
# print(f.readline()) # Read first line
# print(f.readlines()) # Read all lines into a list

# f.close()

# f = open("my.txt", "w")
# f.write("You can Enter any thing")

# f.close()

#Meeting Attendance - Append - (add  at the last)
# while(True):
#     a = input("Enter Your Name: ")
#     f = open("meeting-attendance.txt", "a")
#     f.write(a + "\n")
#     f.close()


# tell() - return the current position of pointer in file

# f = open("meeting-attendance.txt", "r")
# print(f.read(8))
# print(f.tell())
# print(f.read(10))
# print(f.tell())
# f.close()
# total file size - 100000000000000000000000
# every minute - where my pointer 


#seek() - file pointer to a specific position

# f = open("meeting-attendance.txt", "r")
# print(f.read(8))
# f.seek(0) # move pointer to start
# print(f.read(8))
# f.seek(10) # move pointer to a paticular pointer
# f.close()
# Out:
# '\nClass 11\n\nFILE MANAGEMENT / HANDLING\n\n- read\n- update\n\nBenifits\n- Data permanent\n- Share data between programs\n\nTypes of fiels\n1. Text files - (.txt, .csv, .log, .html, .css, .py, .js etc.......)\n2. Binary files - (audio, video, pdf, exe, .jpg, .pdf, .exe, .mp3 etc.........)\n\nBasic file operation\n1. Open a file - open()\n2. Read from file - \n3. Write from file - \n4. Close a file - close()\n\nFile Modes\nr - read (default)\nw - write\na - append (add to end of file)\nb - binary (rb, wb)\nx - create (fails if file exists)\n+ - read and write\n\nLOG FILES - 100GB\nextract - logs related to payment - \ncreate a new file - put only payment logs into it - 3 GB  - 100 Years -> 1 mins\n\nfile scrape data\n- csv data -> excel data\n\n'

# %%
'''
class 12 - EXCEPTION HANDLING
is the process of responding to the occrrence of exception (error)

Without exception handling 
- Your program crashes when an error occur
- User experience become poor

Types of errors
- Syntax error - if x > 5 print(x)
- Name error - print(num) when num is undefined
- Type error - 5 + "hello+
- Value error - int("abc")
- Index error - arr = [1,2] arr[5]
- Key error - d = {} d["x"]
- ZeroDivisionError - 5/0
- FileNotFoundError - open("nofile.txt")

'''

# EXAMPLE 1
# try: 
#     num = int(input("Enter a number : "))
#     result = 10 / num
# except ZeroDivisionError:
#     print("You cannot divide by zero")
# else:
#     print("Division successful : ", result)
# finally: 
#     print("This always runs, no matter what")

# example 2
# try:
#     f = open("meetiing-attendance.txt","r")
#     print(f.read(5))
# except FileNotFoundError:
#     print("File Does Not Exists")
# else:
#     print("Successfully")
# finally:
#     f.close()

# example 3
# try:
#     n = int(input("Enter a Number"))
#     r = n/10
#     f = open("meetiing-attendance.txt","r")
#     f.close()
# except ValueError:
#     print("Plase enter a number")
# except ZeroDivisionError:
#     print("can't divide with zero")
# except FileNotFoundError:
#     print("File not there")
# except Exception as e:
#     print("Error")


# User defind errors
# class Age(Exception):
#     pass

# try:
#     age=int(input("Enter a Error"))
#     if age<18:
#         raise Age
#     else:
#         print("Eligible")
# except Age:
#     print("Not Eligible")
    


# REGULAR EXPRESSIONS - regex
# website - somedomain . something
# email - somename @ websitename . highLevelDomain
# email - omraj@gmail.com
# Indian phone number - 1234567890 - 10 numbers    
    
import re


# # MATCH - match at beginning
# r = re.match(r"hello","hello world")
# print(r)

# SEARCH - search anywhere
# r = re.search(r"w","w hello world w")
# print(r)

# FIND ALL MATCHES
# r = re.findall(r"w","w hello world w")
# print(r)


# # Any digit (0-9)
# text = "I have 2 apples and 3 bananasr"
# r = re.findall(r"\d", text)
# print(r)


# {n} Exactly n times a{3} aaa
# \d Any digit (0-9) \d 1, 2
# text = "call me at 1234567890 or 0987654321 or 12345"
# r=re.findall(r"\d{10}",text)
# print(r)


# ^ Start of string ^Hello Hello world
# $ End of string world$ Hello world
# text = "1234567890"
# r = re.match(r"^\d{10}$",text)
# print(r)


# ^            Start of the string                        ^abc@gmail.com         ✅ Matches
# [\w\.-]+     One or more word chars (a-zA-Z0-9_), 
#              dots (.), or hyphens (-)                   abc.john-doe           ✅ Valid username
# @            Literal '@' symbol                         abc@                   ✅ Present
# [\w\.-]+     One or more word chars, dots, or hyphens   gmail                  ✅ Valid domain
# \.           Literal dot '.'                            gmail.                 ✅ Dot before TLD
# \w+          One or more word characters (letters/digits/_) com               ✅ Valid TLD
# $            End of the string                          abc@gmail.com$         ✅ Matches
# Full regex: ^[\w\.-]+@[\w\.-]+\.\w+$

# email = "abc@gmail.com"
# if re.match(r'^[\w\.-]+@[\w\.-]+\.\w+$', email):
#     print("Valid email address")
# else:
#     print("Invalid email")
