# %% [markdown]
# ### data file is present here : https://drive.google.com/file/d/1Knl92dpOpWcVFVXCytADeC9VguLpDDMc/view?usp=sharing

# %% [markdown]
# ### Case Study 2

# %% [markdown]
# Airbnb

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('airbnb.csv')

# %%
df.head(2)
# Out:
#       id                         listing_url  \
# 0  11156  https://www.airbnb.com/rooms/11156
# 1  12351  https://www.airbnb.com/rooms/12351
#
#                                 name  host_id host_name host_since  \
# 0               An Oasis in the City    40855   Colleen   23/09/09
# 1  Sydney City & Harbour at the door    17061    Stuart   14/05/09
#
#   host_is_superhost host_identity_verified                       street  \
# 0                 t                      f  Potts Point, NSW, Australia
# 1                 f                      t      Pyrmont, NSW, Australia
#
#           city  ... monthly_price security_deposit cleaning_fee  \
# 0  Potts Point  ...           NaN              NaN          NaN
# 1      Pyrmont  ...           NaN           $0.00       $55.00
#
#    guests_included  extra_people has_availability number_of_reviews  \
# 0                1        $0.00                 1               177
# 1                2      $395.00                 1               468
# ...

# %%
df.shape
# Out:
# (27076, 36)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy'],
#       dtype='object')

# %%
df['property_type']
# Out:
# 0                Apartment
# 1                Townhouse
# 2                    House
# 3                Apartment
# 4                Apartment
#                ...
# 27071            Apartment
# 27072                House
# 27073    Bed and breakfast
# 27074                House
# 27075                House
# Name: property_type, Length: 27076, dtype: object

# %%
df['property_type'].head()
# Out:
# 0    Apartment
# 1    Townhouse
# 2        House
# 3    Apartment
# 4    Apartment
# Name: property_type, dtype: object

# %%
df['room_type']
# Out:
# 0           Private room
# 1           Private room
# 2        Entire home/apt
# 3           Private room
# 4            Shared room
#               ...
# 27071       Private room
# 27072    Entire home/apt
# 27073       Private room
# 27074    Entire home/apt
# 27075    Entire home/apt
# Name: room_type, Length: 27076, dtype: object

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df['accommodates'].head()
# Out:
# 0    1
# 1    2
# 2    6
# 3    2
# 4    1
# Name: accommodates, dtype: int64

# %%
# view multiple columns at once - column names : price, weekly_price, monthly_price - head 3

# %%
df[['price', 'weekly_price', 'monthly_price']].head(3)
# Out:
#       price weekly_price monthly_price
# 0   $65.00           NaN           NaN
# 1   $98.00      $800.00            NaN
# 2  $469.00    $3,000.00            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27076 entries, 0 to 27075
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      27076 non-null  int64
#  1   listing_url             27076 non-null  object
#  2   name                    27062 non-null  object
#  3   host_id                 27076 non-null  int64
#  4   host_name               27041 non-null  object
#  5   host_since              27041 non-null  object
#  6   host_is_superhost       27041 non-null  object
#  7   host_identity_verified  27041 non-null  object
#  8   street                  27076 non-null  object
#  9   city                    27043 non-null  object
#  10  state                   27067 non-null  object
#  11  country_code            27076 non-null  object
#  12  country                 27076 non-null  object
#  13  latitude                27076 non-null  float64
# ...

# %%
df.head(3)
# Out:
#       id                         listing_url  \
# 0  11156  https://www.airbnb.com/rooms/11156
# 1  12351  https://www.airbnb.com/rooms/12351
# 2  14250  https://www.airbnb.com/rooms/14250
#
#                                 name  host_id host_name host_since  \
# 0               An Oasis in the City    40855   Colleen   23/09/09
# 1  Sydney City & Harbour at the door    17061    Stuart   14/05/09
# 2                Manly Harbour House    55948     Heidi   20/11/09
#
#   host_is_superhost host_identity_verified                       street  \
# 0                 t                      f  Potts Point, NSW, Australia
# 1                 f                      t      Pyrmont, NSW, Australia
# 2                 f                      t    Balgowlah, NSW, Australia
#
#           city  ... monthly_price security_deposit cleaning_fee  \
# 0  Potts Point  ...           NaN              NaN          NaN
# 1      Pyrmont  ...           NaN           $0.00       $55.00
# ...

# %%
df.sample(3)
# Out:
#              id                            listing_url  \
# 5042    6926770   https://www.airbnb.com/rooms/6926770
# 17696  18011817  https://www.airbnb.com/rooms/18011817
# 9418   11020285  https://www.airbnb.com/rooms/11020285
#
#                                     name    host_id host_name host_since  \
# 5042        Ocean Views at Dee Why Beach   36311507     David   21/06/15
# 17696  ROOM FOR RENT SINGLE OR TWINSHARE  123832678     Jenny    2/04/17
# 9418       Ultra Stylish Palmy Apartment    3231371      Tara   12/08/12
#
#       host_is_superhost host_identity_verified                      street  \
# 5042                  f                      t     Dee Why, NSW, Australia
# 17696                 f                      f  Narraweena, NSW, Australia
# 9418                  f                      t  Palm Beach, NSW, Australia
#
#              city  ... monthly_price security_deposit cleaning_fee  \
# 5042      Dee Why  ...           NaN         $200.00       $75.00
# ...

# %%
df.sample()
# Out:
#            id                           listing_url  \
# 8216  9865161  https://www.airbnb.com/rooms/9865161
#
#                                     name   host_id host_name host_since  \
# 8216  Modern Bondi Apartment Ocean Views  41362615       Mal   13/08/15
#
#      host_is_superhost host_identity_verified                       street  \
# 8216                 f                      t  Bondi Beach, NSW, Australia
#
#              city  ... monthly_price security_deposit cleaning_fee  \
# 8216  Bondi Beach  ...           NaN              NaN          NaN
#
#       guests_included  extra_people has_availability number_of_reviews  \
# 8216                1        $0.00                 1                 0
#
#       review_scores_rating  instant_bookable  cancellation_policy
# 8216                   NaN                 f             flexible
#
# [1 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy'],
#       dtype='object')

# %%
df['amenities']
# Out:
# 0        {TV,Kitchen,Elevator,"Buzzer/wireless intercom...
# 1        {TV,Internet,Wifi,"Air conditioning","Paid par...
# 2        {TV,Wifi,"Air conditioning",Kitchen,"Pets live...
# 3        {Internet,Wifi,"Wheelchair accessible",Pool,Ki...
# 4        {Internet,Wifi,Pool,Kitchen,Gym,Elevator,"Buzz...
#                                ...
# 27071    {Wifi,Kitchen,"Family/kid friendly",Washer,"Sm...
# 27072    {TV,"Cable TV",Wifi,Pool,Kitchen,"Free street ...
# 27073    {TV,Wifi,"Indoor fireplace",Heating,Washer,"Sm...
# 27074    {TV,Internet,Wifi,"Air conditioning",Pool,Kitc...
# 27075    {TV,Wifi,Kitchen,Heating,"Family/kid friendly"...
# Name: amenities, Length: 27076, dtype: object

# %%
df['amenities'].iloc[2]
# Out:
# '{TV,Wifi,"Air conditioning",Kitchen,"Pets live on this property",Cat(s),"Free street parking",Heating,Washer,Dryer,"Smoke detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Hot water","Luggage dropoff allowed",Other}'

# %%
type(df['amenities'].iloc[2])
# Out:
# str

# %%
ami = df['amenities'].iloc[2]
ami
# Out:
# '{TV,Wifi,"Air conditioning",Kitchen,"Pets live on this property",Cat(s),"Free street parking",Heating,Washer,Dryer,"Smoke detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Hot water","Luggage dropoff allowed",Other}'

# %%
ami.split(',')
# Out:
# ['{TV',
#  'Wifi',
#  '"Air conditioning"',
#  'Kitchen',
#  '"Pets live on this property"',
#  'Cat(s)',
#  '"Free street parking"',
#  'Heating',
#  'Washer',
#  'Dryer',
#  '"Smoke detector"',
#  'Essentials',
#  'Shampoo',
#  'Hangers',
#  '"Hair dryer"',
#  'Iron',
#  '"Laptop friendly workspace"',
#  '"Hot water"',
#  '"Luggage dropoff allowed"',
#  'Other}']

# %%
len(ami.split(','))
# Out:
# 20

# %%
def get_amenities_count(amenities):
    return len(amenities.split(','))

# %%
df['amenities'].apply(get_amenities_count)
# Out:
# 0        23
# 1        29
# 2        20
# 3        17
# 4         9
#          ..
# 27071     9
# 27072    20
# 27073    25
# 27074    15
# 27075    31
# Name: amenities, Length: 27076, dtype: int64

# %%
# create a new column for amenities count
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy'],
#       dtype='object')

# %%
df['amenities_count'] = df['amenities'].apply(get_amenities_count)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy',
#        'amenities_count'],
#       dtype='object')

# %%
df['amenities_count']
# Out:
# 0        23
# 1        29
# 2        20
# 3        17
# 4         9
#          ..
# 27071     9
# 27072    20
# 27073    25
# 27074    15
# 27075    31
# Name: amenities_count, Length: 27076, dtype: int64

# %%
df['extra_people']
# Out:
# 0          $0.00
# 1        $395.00
# 2         $40.00
# 3         $40.00
# 4          $0.00
#            ...
# 27071      $0.00
# 27072     $50.00
# 27073     $25.00
# 27074    $100.00
# 27075      $0.00
# Name: extra_people, Length: 27076, dtype: object

# %%
col_to_delete = ['country', 'latitude', 'longitude',
       'property_type', 'room_type']
df.drop(col_to_delete, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy',
#        'amenities_count'],
#       dtype='object')

# %% [markdown]
# ### Look for duplicate rows

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27071     True
# 27072     True
# 27073     True
# 27074     True
# 27075     True
# Length: 27076, dtype: bool

# %%
df[df.duplicated()]
# Out:
#              id                            listing_url  \
# 27070  22151172  https://www.airbnb.com/rooms/22151172
# 27071  16444390  https://www.airbnb.com/rooms/16444390
# 27072  14829119  https://www.airbnb.com/rooms/14829119
# 27073  15918138  https://www.airbnb.com/rooms/15918138
# 27074   8977894   https://www.airbnb.com/rooms/8977894
# 27075  17642461  https://www.airbnb.com/rooms/17642461
#
#                                                     name    host_id  \
# 27070          Sgl rm close to shop/restaurant/transport  159933426
# 27071  1min walk from Coogee beach - awesome double room   67102419
# 27072         Bronte Beach House : Views & Swimming Pool     113874
# 27073                 Brickfield Hill - The Ensuite Room   82600141
# 27074                    Mosman Masterpiece by the Beach   46912165
# 27075    Perfectly located comfortable 3 bedroom terrace   11101996
#
#                        host_name host_since host_is_superhost  \
# ...

# %%
df[df.duplicated(keep=False)]  # original + duplicate instances
# Out:
#              id                            listing_url  \
# 6628    8977894   https://www.airbnb.com/rooms/8977894
# 12829  14829119  https://www.airbnb.com/rooms/14829119
# 14305  15918138  https://www.airbnb.com/rooms/15918138
# 15788  16444390  https://www.airbnb.com/rooms/16444390
# 17239  17642461  https://www.airbnb.com/rooms/17642461
# 25249  22151172  https://www.airbnb.com/rooms/22151172
# 27070  22151172  https://www.airbnb.com/rooms/22151172
# 27071  16444390  https://www.airbnb.com/rooms/16444390
# 27072  14829119  https://www.airbnb.com/rooms/14829119
# 27073  15918138  https://www.airbnb.com/rooms/15918138
# 27074   8977894   https://www.airbnb.com/rooms/8977894
# 27075  17642461  https://www.airbnb.com/rooms/17642461
#
#                                                     name    host_id  \
# 6628                     Mosman Masterpiece by the Beach   46912165
# 12829         Bronte Beach House : Views & Swimming Pool     113874
# ...

# %%
df[df.duplicated()].index
# Out:
# Index([27070, 27071, 27072, 27073, 27074, 27075], dtype='int64')

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#              id                            listing_url  \
# 0         11156     https://www.airbnb.com/rooms/11156
# 1         12351     https://www.airbnb.com/rooms/12351
# 2         14250     https://www.airbnb.com/rooms/14250
# 3         14935     https://www.airbnb.com/rooms/14935
# 4         14974     https://www.airbnb.com/rooms/14974
# ...         ...                                    ...
# 27065  22708135  https://www.airbnb.com/rooms/22708135
# 27066  22708238  https://www.airbnb.com/rooms/22708238
# 27067  22709306  https://www.airbnb.com/rooms/22709306
# 27068  22709315  https://www.airbnb.com/rooms/22709315
# 27069  22709659  https://www.airbnb.com/rooms/22709659
#
#                                                     name    host_id host_name  \
# 0                                   An Oasis in the City      40855   Colleen
# 1                      Sydney City & Harbour at the door      17061    Stuart
# ...

# %%
# Summary

# %%
df.describe()
# Out:
#                  id       host_id  accommodates     bathrooms      bedrooms  \
# count  2.707000e+04  2.707000e+04  27070.000000  27048.000000  27062.000000
# mean   1.402672e+07  4.692847e+07      3.383598      1.352337      1.614071
# std    6.520952e+06  4.525669e+07      2.196864      0.664092      1.109725
# min    1.115600e+04  8.346000e+03      1.000000      0.000000      0.000000
# 25%    9.083668e+06  1.108913e+07      2.000000      1.000000      1.000000
# 50%    1.544074e+07  3.016545e+07      2.000000      1.000000      1.000000
# 75%    2.015561e+07  6.754591e+07      4.000000      1.500000      2.000000
# max    2.270966e+07  1.674985e+08     16.000000     10.000000     46.000000
#
#                beds   square_feet  guests_included  has_availability  \
# count  27037.000000    256.000000     27070.000000           27070.0
# mean       2.012169    421.453125         1.515146               1.0
# std        1.526399   1573.511992         1.256044               0.0
# ...

# %%
# Find the listings without a bathroom
df[df['bathrooms'] == 0]
# Out:
#              id                            listing_url  \
# 1232    2064031   https://www.airbnb.com/rooms/2064031
# 1373    2257635   https://www.airbnb.com/rooms/2257635
# 1934    3334584   https://www.airbnb.com/rooms/3334584
# 2307    4033572   https://www.airbnb.com/rooms/4033572
# 2420    4184110   https://www.airbnb.com/rooms/4184110
# ...         ...                                    ...
# 24923  22069561  https://www.airbnb.com/rooms/22069561
# 25600  22218527  https://www.airbnb.com/rooms/22218527
# 25769  22265628  https://www.airbnb.com/rooms/22265628
# 25993  22309457  https://www.airbnb.com/rooms/22309457
# 26636  22485646  https://www.airbnb.com/rooms/22485646
#
#                                                     name    host_id  \
# 1232      Bondi Large Room w/- Private access to balcony   10561496
# 1373                      Twin Shared Room in Uni Campus   11279706
# 1934                                           Bondi Pad    3611086
# ...

# %%
df[df['beds'] == 0]
# Out:
#              id                            listing_url  \
# 91       264925    https://www.airbnb.com/rooms/264925
# 149      389876    https://www.airbnb.com/rooms/389876
# 169      420647    https://www.airbnb.com/rooms/420647
# 170      421997    https://www.airbnb.com/rooms/421997
# 171      424931    https://www.airbnb.com/rooms/424931
# ...         ...                                    ...
# 25438  22194078  https://www.airbnb.com/rooms/22194078
# 25534  22210446  https://www.airbnb.com/rooms/22210446
# 26377  22394860  https://www.airbnb.com/rooms/22394860
# 26649  22487326  https://www.airbnb.com/rooms/22487326
# 26655  22488321  https://www.airbnb.com/rooms/22488321
#
#                                                     name    host_id  \
# 91                        Stunning North Bondi Beach Pad    1389838
# 149                      Huge Sydney Apartment + Parking    1943399
# 169                  Newtown Darlington Suites-1st. Flr.    2091917
# ...

# %%
# Is there a listing without a bedroom, bathroom and bed
df.query('beds == 0 and bathrooms == 0 and bedrooms == 0')
# Out:
# Empty DataFrame
# Columns: [id, listing_url, name, host_id, host_name, host_since, host_is_superhost, host_identity_verified, street, city, state, country_code, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, has_availability, number_of_reviews, review_scores_rating, instant_bookable, cancellation_policy, amenities_count]
# Index: []
#
# [0 rows x 32 columns]

# %%
df[(df['beds']==0) & (df['bathrooms']==0) & (df['bedrooms']==0)]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, name, host_id, host_name, host_since, host_is_superhost, host_identity_verified, street, city, state, country_code, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, has_availability, number_of_reviews, review_scores_rating, instant_bookable, cancellation_policy, amenities_count]
# Index: []
#
# [0 rows x 32 columns]

# %%
df[(df['beds']==0) | (df['bathrooms']==0) | (df['bedrooms']==0)]
# Out:
#              id                            listing_url  \
# 16        63795     https://www.airbnb.com/rooms/63795
# 91       264925    https://www.airbnb.com/rooms/264925
# 128      348891    https://www.airbnb.com/rooms/348891
# 147      387130    https://www.airbnb.com/rooms/387130
# 149      389876    https://www.airbnb.com/rooms/389876
# ...         ...                                    ...
# 27012  22679407  https://www.airbnb.com/rooms/22679407
# 27020  22689848  https://www.airbnb.com/rooms/22689848
# 27027  22691962  https://www.airbnb.com/rooms/22691962
# 27058  22706892  https://www.airbnb.com/rooms/22706892
# 27065  22708135  https://www.airbnb.com/rooms/22708135
#
#                                                     name    host_id  \
# 16                        Tree Tops Retreat Avalon Beach     311659
# 91                        Stunning North Bondi Beach Pad    1389838
# 128                         Ruby's Oasis on Bondi Beach!     201611
# ...

# %%
df['has_availability']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 27065    1
# 27066    1
# 27067    1
# 27068    1
# 27069    1
# Name: has_availability, Length: 27070, dtype: int64

# %%
df['has_availability'].unique()
# Out:
# array([1], dtype=int64)

# %%
df['has_availability'].std()
# Out:
# 0.0

# %%
df['has_availability'].var()
# Out:
# 0.0

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy',
#        'amenities_count'],
#       dtype='object')

# %%
df.drop('has_availability', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'number_of_reviews', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy', 'amenities_count'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id       host_id  accommodates     bathrooms      bedrooms  \
# count  2.707000e+04  2.707000e+04  27070.000000  27048.000000  27062.000000
# mean   1.402672e+07  4.692847e+07      3.383598      1.352337      1.614071
# std    6.520952e+06  4.525669e+07      2.196864      0.664092      1.109725
# min    1.115600e+04  8.346000e+03      1.000000      0.000000      0.000000
# 25%    9.083668e+06  1.108913e+07      2.000000      1.000000      1.000000
# 50%    1.544074e+07  3.016545e+07      2.000000      1.000000      1.000000
# 75%    2.015561e+07  6.754591e+07      4.000000      1.500000      2.000000
# max    2.270966e+07  1.674985e+08     16.000000     10.000000     46.000000
#
#                beds   square_feet  guests_included  number_of_reviews  \
# count  27037.000000    256.000000     27070.000000       27070.000000
# mean       2.012169    421.453125         1.515146          14.005689
# std        1.526399   1573.511992         1.256044          29.808917
# ...

# %%
df.describe(include=object)
# Out:
#                                listing_url               name host_name  \
# count                                27070              27056     27035
# unique                               27070              26556      6398
# top     https://www.airbnb.com/rooms/11156  Bondi Beach House     David
# freq                                     1                 13       287
#
#        host_since host_is_superhost host_identity_verified  \
# count       27035             27035                  27035
# unique       2590                 2                      2
# top      10/07/13                 f                      f
# freq          157             23616                  14323
#
#                              street         city  state country_code  \
# count                         27070        27037  27061        27070
# unique                          773          741     16            1
# top     Bondi Beach, NSW, Australia  Bondi Beach    NSW           AU
# ...

# %%
df['host_is_superhost'].value_counts()
# Out:
# host_is_superhost
# f    23616
# t     3419
# Name: count, dtype: int64

# %%
df['host_identity_verified'].value_counts()
# Out:
# host_identity_verified
# f    14323
# t    12712
# Name: count, dtype: int64

# %%
df['monthly_price'].value_counts()
# Out:
# monthly_price
# $2,000.00     100
# $3,000.00      77
# $3,500.00      68
# $1,600.00      61
# $2,500.00      60
#              ...
# $3,479.00       1
# $1,827.00       1
# $8,900.00       1
# $1,602.00       1
# $1,443.00       1
# Name: count, Length: 650, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'number_of_reviews', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy', 'amenities_count'],
#       dtype='object')

# %%
df.drop('monthly_price', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'number_of_reviews', 'review_scores_rating', 'instant_bookable',
#        'cancellation_policy', 'amenities_count'],
#       dtype='object')

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    16922
# Private room        9757
# Shared room          397
# Name: count, dtype: int64

# %%
df['room_type'].mode()
# Out:
# 0    Entire home/apt
# Name: room_type, dtype: object

# %%
df['bed_type'].value_counts()
# Out:
# bed_type
# Real Bed         26864
# Pull-out Sofa      109
# Futon               57
# Airbed              25
# Couch               21
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27076 entries, 0 to 27075
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      27076 non-null  int64
#  1   listing_url             27076 non-null  object
#  2   name                    27062 non-null  object
#  3   host_id                 27076 non-null  int64
#  4   host_name               27041 non-null  object
#  5   host_since              27041 non-null  object
#  6   host_is_superhost       27041 non-null  object
#  7   host_identity_verified  27041 non-null  object
#  8   street                  27076 non-null  object
#  9   city                    27043 non-null  object
#  10  state                   27067 non-null  object
#  11  country_code            27076 non-null  object
#  12  country                 27076 non-null  object
#  13  latitude                27076 non-null  float64
# ...

# %%
df.describe(include=object)
# Out:
#                                   listing_url                   name  \
# count                                   27076                  27062
# unique                                  27070                  26556
# top     https://www.airbnb.com/rooms/17642461  Bondi Beach Apartment
# freq                                        2                     13
#
#        host_name host_since host_is_superhost host_identity_verified  \
# count      27041      27041             27041                  27041
# unique      6398       2590                 2                      2
# top        David   10/07/13                 f                      f
# freq         288        157             23622                  14326
#
#                              street         city  state country_code  ...  \
# count                         27076        27043  27067        27076  ...
# unique                          773          741     16            1  ...
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude  accommodates  \
# count  2.707600e+04  2.707600e+04  27076.000000  27076.000000  27076.000000
# mean   1.402716e+07  4.693166e+07    -33.862373    151.210673      3.383845
# std    6.520554e+06  4.525899e+07      0.072255      0.079443      2.197200
# min    1.115600e+04  8.346000e+03    -34.135212    150.644964      1.000000
# 25%    9.083893e+06  1.109524e+07    -33.897607    151.184480      2.000000
# 50%    1.544105e+07  3.017023e+07    -33.883071    151.223246      2.000000
# 75%    2.015550e+07  6.754962e+07    -33.831867    151.264882      4.000000
# max    2.270966e+07  1.674985e+08    -33.389728    151.339811     16.000000
#
#           bathrooms      bedrooms          beds   square_feet  \
# count  27054.000000  27068.000000  27043.000000    256.000000
# mean       1.352443      1.614231      2.012462    421.453125
# std        0.664248      1.109976      1.527099   1573.511992
# ...

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    16922
# Private room        9757
# Shared room          397
# Name: count, dtype: int64

# %%
df['room_type'].mode()
# Out:
# 0    Entire home/apt
# Name: room_type, dtype: object

# %%
df['price'].iloc[0]
# Out:
# '$65.00 '

# %%
df['price'].iloc[0].replace('$','')
# Out:
# '65.00 '

# %%
df['price'].iloc[0].lstrip('$')
# Out:
# str

# %%
float(df['price'].iloc[0].replace('$',''))
# Out:
# 65.0

# %%
type(float(df['price'].iloc[0].replace('$','')))
# Out:
# float

# %%
def convert_price_into_float(price_in_str):
    return float(price_in_str.strip().replace('$','').replace(',',''))

# %%
df['price'].apply(convert_price_into_float)
# Out:
# 0         65.0
# 1         98.0
# 2        469.0
# 3         63.0
# 4         39.0
#          ...
# 27071    100.0
# 27072    929.0
# 27073    165.0
# 27074    950.0
# 27075    229.0
# Name: price, Length: 27076, dtype: float64

# %%
df['price'] = df['price'].apply(convert_price_into_float)

# %%
df['price']
# Out:
# 0         65.0
# 1         98.0
# 2        469.0
# 3         63.0
# 4         39.0
#          ...
# 27071    100.0
# 27072    929.0
# 27073    165.0
# 27074    950.0
# 27075    229.0
# Name: price, Length: 27076, dtype: float64

# %%
df['price'].describe()
# Out:
# count    27076.000000
# mean       209.321539
# std        304.369876
# min          0.000000
# 25%         80.000000
# 50%        135.000000
# 75%        229.000000
# max      12999.000000
# Name: price, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy'],
#       dtype='object')

# %%
df[[ 'name', 'host_id', 'host_name', 'host_since']].isna().sum()
# Out:
# name          14
# host_id        0
# host_name     35
# host_since    35
# dtype: int64

# %%
def convert_price_to_float(price_in_str):
    if isinstance(price_in_str, str):
        return float(price_in_str.strip().replace('$','').replace(',',''))
    else: 
        return price_in_str

# %%
df['cleaning_fee'] = df['cleaning_fee'].apply(convert_price_to_float)

# %%
df['cleaning_fee']
# Out:
# 0          NaN
# 1         55.0
# 2        100.0
# 3          NaN
# 4          NaN
#          ...
# 27071      NaN
# 27072    425.0
# 27073      NaN
# 27074    390.0
# 27075    120.0
# Name: cleaning_fee, Length: 27076, dtype: float64

# %%
df.describe(include=object)
# Out:
#                                   listing_url                   name  \
# count                                   27076                  27062
# unique                                  27070                  26556
# top     https://www.airbnb.com/rooms/17642461  Bondi Beach Apartment
# freq                                        2                     13
#
#        host_name host_since host_is_superhost host_identity_verified  \
# count      27041      27041             27041                  27041
# unique      6398       2590                 2                      2
# top        David   10/07/13                 f                      f
# freq         288        157             23622                  14326
#
#                              street         city  state country_code  ...  \
# count                         27076        27043  27067        27076  ...
# unique                          773          741     16            1  ...
# ...

# %%
df['host_since']
# Out:
# 0        23/09/09
# 1        14/05/09
# 2        20/11/09
# 3        30/11/09
# 4        30/11/09
#            ...
# 27071    13/04/16
# 27072    26/04/10
# 27073     9/07/16
# 27074    19/10/15
# 27075     7/01/14
# Name: host_since, Length: 27076, dtype: object

# %%
df['host_since'].iloc[0]
# Out:
# '23/09/09'

# %%
pd.to_datetime(df['host_since'])
# Out:
# C:\Users\khanf\AppData\Local\Temp\ipykernel_17608\2993864240.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['host_since'])
# 0       2009-09-23
# 1       2009-05-14
# 2       2009-11-20
# 3       2009-11-30
# 4       2009-11-30
#            ...
# 27071   2016-04-13
# 27072   2010-04-26
# 27073   2016-09-07
# 27074   2015-10-19
# 27075   2014-07-01
# Name: host_since, Length: 27076, dtype: datetime64[ns]

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
df['host_since'] = pd.to_datetime(df['host_since'])

# %%
df['host_since']
# Out:
# 0       2009-09-23
# 1       2009-05-14
# 2       2009-11-20
# 3       2009-11-30
# 4       2009-11-30
#            ...
# 27071   2016-04-13
# 27072   2010-04-26
# 27073   2016-09-07
# 27074   2015-10-19
# 27075   2014-07-01
# Name: host_since, Length: 27076, dtype: datetime64[ns]

# %% [markdown]
# ### Check for null/Nan/missing values

# %%
df.isna().sum()
# Out:
# id                            0
# listing_url                   0
# name                         14
# host_id                       0
# host_name                    35
# host_since                   35
# host_is_superhost            35
# host_identity_verified       35
# street                        0
# city                         33
# state                         9
# country_code                  0
# country                       0
# latitude                      0
# longitude                     0
# property_type                 0
# room_type                     0
# accommodates                  0
# bathrooms                    22
# bedrooms                      8
# beds                         33
# bed_type                      0
# amenities                     0
# square_feet               26820
# price                         0
# weekly_price              23155
# monthly_price             24701
# security_deposit          10351
# cleaning_fee               7823
# ...

# %%
missing_val = df.isna().sum()

# %%
missing_val[missing_val > 0]
# Out:
# name                         14
# host_name                    35
# host_since                   35
# host_is_superhost            35
# host_identity_verified       35
# city                         33
# state                         9
# bathrooms                    22
# bedrooms                      8
# beds                         33
# square_feet               26820
# weekly_price              23155
# monthly_price             24701
# security_deposit          10351
# cleaning_fee               7823
# review_scores_rating       7559
# dtype: int64

# %%
missing_val[missing_val > 0] / len(df) * 100
# Out:
# name                       0.051706
# host_name                  0.129266
# host_since                 0.129266
# host_is_superhost          0.129266
# host_identity_verified     0.129266
# city                       0.121879
# state                      0.033240
# bathrooms                  0.081253
# bedrooms                   0.029546
# beds                       0.121879
# square_feet               99.054513
# weekly_price              85.518540
# monthly_price             91.228394
# security_deposit          38.229428
# cleaning_fee              28.892746
# review_scores_rating      27.917713
# dtype: float64

# %%
len(df)
# Out:
# 27076

# %%
sns.heatmap(df.isna())
plt.show()

# %%
sns.heatmap(df.isna(), cmap='coolwarm')
plt.show()

# %%
sns.heatmap(df.isna(), cmap='viridis')
plt.show()
