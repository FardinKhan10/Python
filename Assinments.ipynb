# %%
"""
Conditionals
"""
# 1. **Check Voting Eligibility**
#     - Input: Age
#     - Output: Eligible or not based on age ≥ 18
# age = int(input("Enter Your Age To check Your Eligibility:"))
# if age >= 18:
#     print("Eligibility")

# else:
#     print("Not Eligibility")

# 2. **Even or Odd Checker**
#     - Input: Any number
#     - Output: Even or Odd
# num = int(input("Enter a Number to  Check Even or Odd:"))
# if num % 2 == 0:
#     print("Even Number")
    
# else:
#     print("Odd Number")

# 5. **Leap Year Checker**
#     - Input: Year
#     - Output: Whether it's a leap year or not
# year = int(input("Enter a Year:"))
# if year % 4 == 0 & year % 100 == 0 & year % 400 == 0:
#     print("Year is a Leap Year")
    
# else:
#     print("Not Leap Year")

# 7. **Number is Positive, Negative, or Zero**
#     - Input: Integer
#     - Output: Positive, Negative, or Zero
# num = int(input("Enter a Number:"))
# if num > 0:
#     print("Number is Positive")
    
# elif num < 0:
#     print("Number is Negative")

# else:
#      print("Number is Zero")

# 8. **Login Simulation**
#     - Input: Username and password
#     - Output: Login successful or not (assume default creds)
# userName = (input("Enter Your Username:"))
# password = int(input("Enter Your Password:"))
# uName = "Fardin"
# pword = 123123
# if userName == uName: 
#     if password  == pword:
#         print("Login successful")
    
# else:
#     print("Invalid UserName & Password......")

# 3. **Find the Greatest of Three Numbers**
#     - Input: 3 numbers
#     - Output: Largest number
# a = int(input("Enter first number: "))
# b = int(input("Enter second number: "))
# c = int(input("Enter third number: "))

# if a >= b and a >= c:
#     print(a)
# elif b >= a and b >= c:
#     print(b)
# else:
#     print(c)

"""
Loops
"""

# 1. **Print 1 to 100**
#     - Use `for` and `while` separately

# for i in range(1,101):
#     print(i)
# i= 0   
# while i <=100:
#     print(i)
#     i = i + 1

# 2. **Sum of N Natural Numbers**
#     - Input: N
#     - Output: Sum from 1 to N
# num = int(input("Enter a Number:")) 
# i = 1
# total = 0
# while i <=num:
#     total = total + i
#     i = i + 1
# print(total)
# Out:
# Enter a Number: 2
# 3

# %%
# 1. Character Extraction
# Write a program to:
# Accept a string input from the user
# Print the first, last, and middle character of the string
# 2. Palindrome Check
# Write a program to:
# Accept a string
# Check if it’s a palindrome (same forwards and backwards)
# Ignore case and spaces
# Example:
# python
# CopyEdit
# Input: "Madam"
# Output: True


# ​
# 3. Word Count
# Accept a string and print:
# Total number of characters
# Total number of words
# Total number of spaces
# 4. Vowel Count
# Write a program that counts the number of each vowel (a, e, i, o, u) in a string.
# 5. Password Validator
# Check whether a password is valid:
# At least 8 characters
# Contains at least one uppercase letter
# Contains at least one lowercase letter
# Contains at least one digit
# 6. String Formatter
# Accept name, age, and city from user and print:
# python
# CopyEdit
# "Hello, my name is [name]. I am [age] years old and I live in [city]."



# Use .format() or f-strings.
# 7. String Compression
# Take a string like "aaabbccc" and convert it to "a3b2c3".
# 8. Digit Extractor
# Write a program that:
# Accepts a string
# Extracts and prints only the digits from it
# 9. Find the Most Frequent Character
# Input a string and output the character that occurs most frequently.
# 10. Word Reverser
# Input a sentence and print:
# Each word reversed but order preserved
# Example:
# python
# CopyEdit
# Input: "Hello World"
# Output: "olleH dlroW"



"""
Strings
"""

# 1. Character Extraction
# Write a program to:
# Accept a string input from the user
# Print the first, last, and middle character of the string

# name = input("Enter Your Name:")
# print(name[:1])
# print(name[:])

# arr = [4,5,7,6,4,9,10,12,8,6]
# maxx = -1
# secmaxx = -1
# for a in arr:
#     if a > maxx:
#         maxx = a

# print(maxx)

# for a in arr:
#     if a > maxx:
#         secmaxx = maxx
#         maxx = a
#     if a != maxx and a>secmaxx:
#         secmaxx = a

# print(secmaxx)

# def fac(num):
#     result = 1
#     for i in range(1, num+1):
#         result = result*i
#     return result

# try:
#     num = int(input("Enter a Number"))
#     if num < 0:
#         raise ValueError("Negative number entered. Invalid input")
#     print(fac(num))    
# except Exception as e:
#     print(e)
# Out:
#   Cell In[5], line 107
#     print(f"{num}"*"{i}"{num*i})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# # find highest element
# nums =[6,3,2,3,6,8,5,3,19,2,4,6,7,0]
# maxx = -1

# for num in nums:
#     if num > maxx:
#         maxx = num

# print(maxx)


# find second highest element
# nums =[6,3,2,3,6,8,5,3,19,2,4,6,7,0]
# maxEl = -1
# secondMaxEl = -1
# for num in nums:
#     if num > maxEl:
#         secondMaxEl = maxEl
#         maxEl = num
#     if num != maxEl and num > secondMaxEl:
#         secondMaxEl = num
# print(maxEl)
# print(secondMaxEl)

# num = int(input("Enter a Number: "))

# for i in range(1, 11):
#     print(f"{num} * {i} = {num * i}")


# for i in range(1, 101):
#     if i%2==0:
#         print(i)

# for i in range(2,101,2):
#     print(i)

# print sum form 1 - n (take n as input)
# n = int(input("Enter a number: "))
# total = 0

# for i in range(1, n + 1):
#     # total += i
#     total = total + i
# print(total)


# revers a number
# n = 1234
# while(n>0):
#     ln = n % 10
#     print(ln)
#     n//=10  



# n = 1234
# sum =0
# while(n>0):
#     ln = n % 10
#     print(ln)
#     sum += ln
#     n//=10

# print(sum)
# n=5
# for i in range(1,n+1):
#     for j in range(1,)


num = int(input("Enter a Nuber:"))
for i in range(1,11):
    print(f"{num}*{i}={num*i}")
    # print(f"{num} * {i} = {num * i}")
# Out:
# Enter a Nuber: 5
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
